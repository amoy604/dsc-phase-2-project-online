# %% [markdown]
# # Project
#
# This project was created out of my curiousity of flipping properties. Also, other than updating the house itself, what increases the value a property sales at.

# %% [markdown]
# # Built With
#
# * Python
# * Seaborn
# * Pandas
# * Numpy
# * StatsModel

# %% [markdown]
# # Question 1
#
# Does flipping houses actually increase price?
#
# ![Screen%20Shot%202020-11-03%20at%2010.29.50%20AM.png](attachment:Screen%20Shot%202020-11-03%20at%2010.29.50%20AM.png)
#
# Yes it does! It shows that renovated houses have a higher average of prices compared to non-renovated.

# %% [markdown]
# # Question 2
#
# Does the amount of bedrooms and bathrooms effect price?
#
# ![Screen%20Shot%202020-11-03%20at%2010.40.19%20AM.png](attachment:Screen%20Shot%202020-11-03%20at%2010.40.19%20AM.png)
#
# This shows a positive trend between the amount of bedrooms and bathrooms with prices.
# If possible, we should add extra bed and bathrooms to increase selling price.

# %% [markdown]
# # Question 3
#
# Do renovated houses have more living space compared to non-renovated?
#
# ![Screen%20Shot%202020-11-03%20at%2010.42.45%20AM.png](attachment:Screen%20Shot%202020-11-03%20at%2010.42.45%20AM.png)![Screen%20Shot%202020-11-03%20at%2012.17.13%20PM.png](attachment:Screen%20Shot%202020-11-03%20at%2012.17.13%20PM.png)
#
# Yes they do! So it seems other people have also thought of increasing the living space while renovating. Increasing the living space within the property will increase the value. We should look into whenever possible.

# %% [markdown]
# # Regression Model
#
# Using the features such as, the amount of bedrooms, bathrooms, and the amount of living space to build a regression model.
# ![Screen%20Shot%202020-11-03%20at%2012.59.22%20PM.png](attachment:Screen%20Shot%202020-11-03%20at%2012.59.22%20PM.png)![Screen%20Shot%202020-11-03%20at%2012.58.42%20PM.png](attachment:Screen%20Shot%202020-11-03%20at%2012.58.42%20PM.png)
#
# The strong coefficient was the one associated with square footage of living space.
